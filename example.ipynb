# %%
import heatmap

# %%
hmd100 = heatmap.preprocess.HeatmapData(assignment_id=100)

# %%
sections_to_preceptor = {
    "P01": "Ellen",
    "P02": "Sylvia",
    "P03": "Justin",
    "P04": "Jacob",
    "P05": "Andrew",
    "P06": "Josh",
    "P07": "Robert",
    "P07A": "Sylvia",
    "P10": "Phillip",
    "P10A": "Robert",
    "P11": "Ellen",
    "P11A": "Josh",
    "P12": "Dante",
    "P13": "Dante",
    "P14": "Phillip",
}

# %%
heatmap100 = heatmap.draw.build_heatmap(hmd100,
                                        x=heatmap.draw.HeatmapXAxis.TEACHERS,
                                        y=heatmap.draw.HeatmapYAxis.CATEGORIES,
                                        section_to_teacher=sections_to_preceptor)

# %%
heatmap.draw.render_heatmap_data(heatmap100, x_caption="Teachers", y_caption="Categories")
